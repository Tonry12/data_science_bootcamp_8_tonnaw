# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonry12/data_science_bootcamp_8_tonnaw/blob/main/%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B9%82%E0%B8%9B%E0%B8%A3%E0%B9%80%E0%B8%88%E0%B8%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #งานโปรเจค
#
#
# สมาชิกกลุ่ม
# *   List item
# *   List item
# *   List item
# *   List item
# *   List item
# *   List item

# %% [markdown]
# #หัวข้อที่สนใจ
# 1. แต่ละจังหวัดเลือกพรรคอะไรมากที่สุด
# 2. แต่ละเขตของขอนแก่นเลือกพรรคอะไรมากที่สุด
# 3. จากผู้มีสิทธิ์เลือกตั้งของจังหวัดขอนแก่นมีผู้มาใช้สิทธิทั้งหมดกี่คน คิดเป็นทั้งหมดกี่%
# 4. ทั่วทั้งประเทศพรรคที่ได้คะแนนเสียงมากที่สุด 5 อันดับแรก
# 5. ทั่วทั้งขอนแก่นพรรคที่ได้คะแนนเสียงมากที่สุด 5 อันดับแรก
#
# 6. ผู้ใดเป็นส.ส.เเบบเเบ่งเขตที่มีคะเเนนเสียงมากที่สุดในพรรคการเมืองเเต่ละกลุ่ม
# 7. ทั่วทั้งประเทศพรรคที่ได้คะแนนเสียงน้อยที่สุด 5 อันดับแรก
# (ทั้งเเบบไม่ถูกเลือกเลยกับถูกเลือกเเต่น้อย)

# %% [markdown]
# #เตรียมข้อมูล

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive') # เช็คว่าเชื่อมติดหรือไม่
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
result_constituencies_PartyList = pd.read_excel('/content/drive/MyDrive/ectreport66.xlsx',sheet_name='result_constituencies_PartyList')
result_constituencies_Candidate = pd.read_excel('/content/drive/MyDrive/ectreport66.xlsx',sheet_name='result_constituencies_Candidate')
result_constituencies_status = pd.read_excel('/content/drive/MyDrive/ectreport66.xlsx',sheet_name='result_constituencies_status')
info_province = pd.read_excel('/content/drive/MyDrive/ectreport66.xlsx',sheet_name='info_province_re')
info_party_overview = pd.read_excel('/content/drive/MyDrive/ectreport66.xlsx',sheet_name='info_party_overview')
info_constituency = pd.read_excel('/content/drive/MyDrive/ectreport66.xlsx',sheet_name='info_constituency')
Candidate_Constituency = pd.read_excel('/content/drive/MyDrive/ectreport66.xlsx',sheet_name='Candidate_Constituency')
Candidate_PartyList = pd.read_excel('/content/drive/MyDrive/ectreport66.xlsx',sheet_name='Candidate_PartyList')
Candidate_PM = pd.read_excel('/content/drive/MyDrive/ectreport66.xlsx',sheet_name='Candidate_PM')
region = pd.read_excel('/content/drive/MyDrive/ectreport66.xlsx',sheet_name='info_province_re')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# เครียส์MISSing

# %%
info_party_overview[info_party_overview['party_no'].isnull()]
# Out:
#      id  party_no          name  abbr    color  \
# 9   711       NaN  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       NaN     พลังบูรพา   พบ.  #4696d6
# 17  720       NaN     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %%
info_party_overview['party_no']=info_party_overview['party_no'].fillna(99)

# %%
info_party_overview[info_party_overview['party_no'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, party_no, name, abbr, color, logo_url]
# Index: []

# %%
info_constituency[info_constituency['zone'].isnull()]
# Out:
# Empty DataFrame
# Columns: [cons_id, cons_no, prov_id, registered_vote, total_vote_stations, zone]
# Index: []

# %%
import numpy as np
# แทนค่าว่าง
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'RNG', 'อำเภอเมืองระนอง', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'SBR', 'อำเภอเมืองสิงห์บุรี', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'SKM', 'อำเภอเมืองสมุทรสงคราม', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'TRT', 'อำเภอเมืองตราด', info_constituency['zone'])

# %%
info_constituency[info_constituency['zone'].isnull()]
# Out:
# Empty DataFrame
# Columns: [cons_id, cons_no, prov_id, registered_vote, total_vote_stations, zone]
# Index: []

# %% [markdown]
# 1.แต่ละจังหวัดเลือกพรรคอะไรมากที่สุด

# %%
table_merge = result_constituencies_Candidate.merge(Candidate_Constituency, how ='left', left_on='mp_app_id',right_on='mp_app_id')
print(table_merge.shape)
table_merge.head()
# Out:
# (4781, 10)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# 2  https://cdn.ectreport.com/images/mp_candidates...
# 3  https://cdn.ectreport.com/images/mp_candidates...
# 4  https://cdn.ectreport.com/images/mp_candidates...

# %%
table_merge1 = table_merge.merge(info_party_overview, how ='left', left_on='party_id',right_on='id')
print(table_merge1.shape)
table_merge1.head()
# Out:
# (4781, 16)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url   id  party_no  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  706      14.0
# 1  https://cdn.ectreport.com/images/mp_candidates...  709       7.0
# 2  https://cdn.ectreport.com/images/mp_candidates...  712       2.0
# 3  https://cdn.ectreport.com/images/mp_candidates...  742      61.0
# 4  https://cdn.ectreport.com/images/mp_candidates...  761       5.0
#
#               name    abbr    color  \
# 0    ชาติพัฒนากล้า    ชพก.  #233e8a
# 1        ภูมิใจไทย     ภท.  #0c149c
# 2  ประชาธิปไตยใหม่    ปธม.  #eb4138
# 3          คลองไทย   คล.ท.  #0eafeb
# 4    พลังสังคมใหม่  พ.ส.ม.  #eabcc3
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ชาติพัฒ...
# 1  https://cdn.ectreport.com/images/logos/ภูมิใจไ...
# 2  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 3  https://cdn.ectreport.com/images/logos/คลองไทย...
# 4  https://cdn.ectreport.com/images/logos/พลังสัง...

# %%
table_merge2 = table_merge1.merge(result_constituencies_status, how ='left', left_on='cons_id',right_on='cons_id')
print(table_merge2.shape)
table_merge2.head()
# Out:
# (4781, 22)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...             name  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...    ชาติพัฒนากล้า
# 1  https://cdn.ectreport.com/images/mp_candidates...  ...        ภูมิใจไทย
# 2  https://cdn.ectreport.com/images/mp_candidates...  ...  ประชาธิปไตยใหม่
# 3  https://cdn.ectreport.com/images/mp_candidates...  ...          คลองไทย
# 4  https://cdn.ectreport.com/images/mp_candidates...  ...    พลังสังคมใหม่
#
#      abbr    color                                           logo_url prov_id  \
# 0    ชพก.  #233e8a  https://cdn.ectreport.com/images/logos/ชาติพัฒ...     ACR
# 1     ภท.  #0c149c  https://cdn.ectreport.com/images/logos/ภูมิใจไ...     ACR
# 2    ปธม.  #eb4138  https://cdn.ectreport.com/images/logos/ประชาธิ...     ACR
# 3   คล.ท.  #0eafeb  https://cdn.ectreport.com/images/logos/คลองไทย...     ACR
# 4  พ.ส.ม.  #eabcc3  https://cdn.ectreport.com/images/logos/พลังสัง...     ACR
#
#   turn_out percent_turn_out  counted_vote_stations  percent_count  \
# 0   105574         72.60136                    310          100.0
# 1   105574         72.60136                    310          100.0
# 2   105574         72.60136                    310          100.0
# 3   105574         72.60136                    310          100.0
# 4   105574         72.60136                    310          100.0
#
#    pause_report
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 22 columns]

# %%
table_merge3 = table_merge2.merge(info_province, how ='left', left_on='prov_id',right_on='prov_id')
print(table_merge3.shape)
table_merge3.head()
# Out:
# (4781, 30)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...  percent_count  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 1  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 2  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 3  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 4  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
#
#    pause_report province_id    province            eng abbre_thai  \
# 0         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 1         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 2         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 3         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 4         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
#
#   total_registered_vote  total_vote_stations  region_id            region_name
# 0                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 1                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 2                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 3                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 4                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
#
# [5 rows x 30 columns]

# %%
table_merge3 = table_merge2.merge(info_province, how ='left', left_on='prov_id',right_on='prov_id')
print(table_merge3.shape)
table_merge3.head()
# Out:
# (4781, 30)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...  percent_count  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 1  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 2  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 3  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 4  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
#
#    pause_report province_id    province            eng abbre_thai  \
# 0         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 1         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 2         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 3         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 4         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
#
#   total_registered_vote  total_vote_stations  region_id            region_name
# 0                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 1                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 2                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 3                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 4                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
#
# [5 rows x 30 columns]

# %%
table_merge4 = table_merge3.merge(region, how ='left', left_on='region_id',right_on='region_id')
print(table_merge3.shape)
table_merge4.head()
# Out:
# (4781, 30)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1   ACR_1_1            9          459              0.43477       706
# 2   ACR_1   ACR_1_1            9          459              0.43477       706
# 3   ACR_1   ACR_1_1            9          459              0.43477       706
# 4   ACR_1   ACR_1_1            9          459              0.43477       706
#
#              mp_app_name  mp_app_no  mp_app_party_id  \
# 0  นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสาวปิยะมาศ บัวแก้ว          1              706
# 2  นางสาวปิยะมาศ บัวแก้ว          1              706
# 3  นางสาวปิยะมาศ บัวแก้ว          1              706
# 4  นางสาวปิยะมาศ บัวแก้ว          1              706
#
#                                            image_url  ...  region_id  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...        R02
# 1  https://cdn.ectreport.com/images/mp_candidates...  ...        R02
# 2  https://cdn.ectreport.com/images/mp_candidates...  ...        R02
# 3  https://cdn.ectreport.com/images/mp_candidates...  ...        R02
# 4  https://cdn.ectreport.com/images/mp_candidates...  ...        R02
#
#            region_name_x province_id_y prov_id_y  province_y          eng_y  \
# 0  ภาคตะวันออกเฉียงเหนือ            37       ACR  อำนาจเจริญ  AMNAT CHAROEN
# 1  ภาคตะวันออกเฉียงเหนือ            38       BKN      บึงกาฬ      BUENG KAN
# 2  ภาคตะวันออกเฉียงเหนือ            31       BRM   บุรีรัมย์       BURI RAM
# 3  ภาคตะวันออกเฉียงเหนือ            36       CPM     ชัยภูมิ     CHAIYAPHUM
# 4  ภาคตะวันออกเฉียงเหนือ            40       KKN     ขอนแก่น      KHON KAEN
#
#   abbre_thai_y  total_registered_vote_y  total_vote_stations_y  \
# 0           อจ                   301354                    641
# 1           บก                   327745                    652
# 2           บร                  1250148                   2568
# 3           ชย                   902888                   1948
# 4           ขก                  1449595                   2679
#
#            region_name_y
# 0  ภาคตะวันออกเฉียงเหนือ
# 1  ภาคตะวันออกเฉียงเหนือ
# 2  ภาคตะวันออกเฉียงเหนือ
# 3  ภาคตะวันออกเฉียงเหนือ
# 4  ภาคตะวันออกเฉียงเหนือ
#
# [5 rows x 38 columns]

# %% [markdown]
# #ข้อ 1

# %%
find_ma = result_constituencies_PartyList.sort_values(by='party_list_vote',ascending=False)
find_ma1 = find_ma.merge(info_constituency,how='left', on='cons_id')
find_ma2 = find_ma1.merge(info_province,how='left', on='prov_id')
find_ma3 = find_ma2.merge(info_party_overview,how='left', left_on='party_id',right_on='id')
find_ma4 = find_ma3.merge(Candidate_Constituency,how='left', on='mp_app_id')
find_ma4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-d58bcf1e4443> in <cell line: 5>()
#       3 find_ma2 = find_ma1.merge(info_province,how='left', on='prov_id')
#       4 find_ma3 = find_ma2.merge(info_party_overview,how='left', left_on='party_id',right_on='id')
# ----> 5 find_ma4 = find_ma3.merge(Candidate_Constituency,how='left', on='mp_app_id')
#       6 find_ma4
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10091         from pandas.core.reshape.merge import merge
#   10092
# > 10093         return merge(
#   10094             self,
#   10095             right,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     701             self.right_join_keys,
#     702             self.join_names,
# --> 703         ) = self._get_merge_keys()
#     704
#     705         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1177                         #  the latter of which will raise
#    1178                         lk = cast(Hashable, lk)
# -> 1179                         left_keys.append(left._get_label_or_level_values(lk))
#    1180                         join_names.append(lk)
#    1181                     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#
# KeyError: 'mp_app_id'

# %%
find_ma4 = find_ma3[['province','name','mp_app_name']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-1476bf83f3d3> in <cell line: 1>()
# ----> 1 find_ma4 = find_ma3[['province','name','mp_app_name']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133             raise KeyError(f"{not_found} not in index")
#    6134
#    6135     @overload
#
# KeyError: "['mp_app_name'] not in index"

# %%
find_ma = result_constituencies_PartyList.sort_values(by='party_list_vote',ascending=False)
find_ma1 = find_ma.merge(info_constituency,how='left', on='cons_id')
find_ma2 = find_ma1.merge(info_province,how='left', on='prov_id')
find_ma3 = find_ma2.merge(info_party_overview,how='left', left_on='party_id',right_on='id')
find_ma4 = find_ma3.merge(Candidate_PartyList,how='left', on='party_no')

# %%
find_ma2
# Out:
#       cons_id  party_id  party_list_vote  party_list_vote_percent  cons_no  \
# 0       RET_2       705            83851                 87.01847        2
# 1       RET_2       705            83851                 87.01847        2
# 2       RET_2       705            83851                 87.01847        2
# 3       RET_2       705            83851                 87.01847        2
# 4       RET_2       705            83851                 87.01847        2
# ...       ...       ...              ...                      ...      ...
# 76107   PBI_3       745                0                  0.00000        3
# 76108   PBI_3       745                0                  0.00000        3
# 76109   PBI_3       745                0                  0.00000        3
# 76110   PBI_3       745                0                  0.00000        3
# 76111   PBI_3       745                0                  0.00000        3
#
#       prov_id  registered_vote  total_vote_stations_x  \
# 0         RET           136456                    362
# 1         RET           136456                    362
# 2         RET           136456                    362
# 3         RET           136456                    362
# 4         RET           136456                    362
# ...       ...              ...                    ...
# 76107     PBI           129624                    274
# 76108     PBI           129624                    274
# 76109     PBI           129624                    274
# 76110     PBI           129624                    274
# 76111     PBI           129624                    274
#
#                                                     zone  province_id  \
# 0                                         อำเภอเชียงขวัญ           45
# 1                                          อำเภอโพธิ์ชัย           45
# 2      อำเภอโพนทอง (เฉพาะตำบลอุ่มเม่า, ตำบลนาอุดม, ตำ...           45
# 3                                            อำเภอจังหาร           45
# 4      อำเภอธวัชบุรี (เฉพาะตำบลหนองพอก, ตำบลธวัชบุรี,...           45
# ...                                                  ...          ...
# 76107                                       อำเภอเขาย้อย           76
# 76108                                    อำเภอแก่งกระจาน           76
# 76109  อำเภอบ้านแหลม (เฉพาะตำบลบ้านแหลม, ตำบลบางตะบูน...           76
# 76110                                       อำเภอบ้านลาด           76
# 76111                                 อำเภอหนองหญ้าปล้อง           76
#
#        province          eng abbre_thai  total_registered_vote  \
# 0      ร้อยเอ็ด       ROI ET         รอ                1054706
# 1      ร้อยเอ็ด       ROI ET         รอ                1054706
# 2      ร้อยเอ็ด       ROI ET         รอ                1054706
# 3      ร้อยเอ็ด       ROI ET         รอ                1054706
# 4      ร้อยเอ็ด       ROI ET         รอ                1054706
# ...         ...          ...        ...                    ...
# 76107  เพชรบุรี  PHETCHABURI         พบ                 389060
# 76108  เพชรบุรี  PHETCHABURI         พบ                 389060
# 76109  เพชรบุรี  PHETCHABURI         พบ                 389060
# 76110  เพชรบุรี  PHETCHABURI         พบ                 389060
# 76111  เพชรบุรี  PHETCHABURI         พบ                 389060
#
#        total_vote_stations_y region_id            region_name
# 0                       2525       R02  ภาคตะวันออกเฉียงเหนือ
# 1                       2525       R02  ภาคตะวันออกเฉียงเหนือ
# 2                       2525       R02  ภาคตะวันออกเฉียงเหนือ
# 3                       2525       R02  ภาคตะวันออกเฉียงเหนือ
# 4                       2525       R02  ภาคตะวันออกเฉียงเหนือ
# ...                      ...       ...                    ...
# 76107                    703       R05             ภาคตะวันตก
# 76108                    703       R05             ภาคตะวันตก
# 76109                    703       R05             ภาคตะวันตก
# 76110                    703       R05             ภาคตะวันตก
# 76111                    703       R05             ภาคตะวันตก
#
# [76112 rows x 17 columns]

# %%
find_ma4
# Out:
#         cons_id  party_id  party_list_vote  party_list_vote_percent  cons_no  \
# 0         RET_2       705            83851                 87.01847        2
# 1         RET_2       705            83851                 87.01847        2
# 2         RET_2       705            83851                 87.01847        2
# 3         RET_2       705            83851                 87.01847        2
# 4         RET_2       705            83851                 87.01847        2
# ...         ...       ...              ...                      ...      ...
# 2156123   PBI_3       745                0                  0.00000        3
# 2156124   PBI_3       745                0                  0.00000        3
# 2156125   PBI_3       745                0                  0.00000        3
# 2156126   PBI_3       745                0                  0.00000        3
# 2156127   PBI_3       745                0                  0.00000        3
#
#         prov_id  registered_vote  total_vote_stations_x                zone  \
# 0           RET           136456                    362      อำเภอเชียงขวัญ
# 1           RET           136456                    362      อำเภอเชียงขวัญ
# 2           RET           136456                    362      อำเภอเชียงขวัญ
# 3           RET           136456                    362      อำเภอเชียงขวัญ
# 4           RET           136456                    362      อำเภอเชียงขวัญ
# ...         ...              ...                    ...                 ...
# 2156123     PBI           129624                    274  อำเภอหนองหญ้าปล้อง
# 2156124     PBI           129624                    274  อำเภอหนองหญ้าปล้อง
# 2156125     PBI           129624                    274  อำเภอหนองหญ้าปล้อง
# 2156126     PBI           129624                    274  อำเภอหนองหญ้าปล้อง
# 2156127     PBI           129624                    274  อำเภอหนองหญ้าปล้อง
#
#          province_id  ...            region_name   id party_no     name_x  \
# 0                 45  ...  ภาคตะวันออกเฉียงเหนือ  705     29.0   เพื่อไทย
# 1                 45  ...  ภาคตะวันออกเฉียงเหนือ  705     29.0   เพื่อไทย
# 2                 45  ...  ภาคตะวันออกเฉียงเหนือ  705     29.0   เพื่อไทย
# 3                 45  ...  ภาคตะวันออกเฉียงเหนือ  705     29.0   เพื่อไทย
# 4                 45  ...  ภาคตะวันออกเฉียงเหนือ  705     29.0   เพื่อไทย
# ...              ...  ...                    ...  ...      ...        ...
# 2156123           76  ...             ภาคตะวันตก  745     53.0  พลังสังคม
# 2156124           76  ...             ภาคตะวันตก  745     53.0  พลังสังคม
# 2156125           76  ...             ภาคตะวันตก  745     53.0  พลังสังคม
# 2156126           76  ...             ภาคตะวันตก  745     53.0  พลังสังคม
# 2156127           76  ...             ภาคตะวันตก  745     53.0  พลังสังคม
#
#            abbr    color                                           logo_url  \
# 0           พท.  #da3731  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 1           พท.  #da3731  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 2           พท.  #da3731  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 3           พท.  #da3731  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4           พท.  #da3731  https://cdn.ectreport.com/images/logos/เพื่อไท...
# ...         ...      ...                                                ...
# 2156123  พ.พ.ส.  #c67328  https://cdn.ectreport.com/images/logos/พลังสัง...
# 2156124  พ.พ.ส.  #c67328  https://cdn.ectreport.com/images/logos/พลังสัง...
# 2156125  พ.พ.ส.  #c67328  https://cdn.ectreport.com/images/logos/พลังสัง...
# 2156126  พ.พ.ส.  #c67328  https://cdn.ectreport.com/images/logos/พลังสัง...
# 2156127  พ.พ.ส.  #c67328  https://cdn.ectreport.com/images/logos/พลังสัง...
#
#          list_no                           name_y  \
# 0              1      พลตำรวจโท วิโรจน์ เปาอินทร์
# 1              2             นายสมพงษ์ อมรวิวัฒน์
# 2              3          นายประเสริฐ จันทรรวงทอง
# 3              4  รองศาสตราจารย์ ชูศักดิ์ ศิรินิล
# 4              5     ร้อยตำรวจเอก เฉลิม อยู่บำรุง
# ...          ...                              ...
# 2156123       10              นางสาวพัชรี เย็นแพง
# 2156124       11     นางสาวพรรณลักษณ์ นพลักษณ์กุล
# 2156125       12                   นายพิทัต ผลทวี
# 2156126       13           นางสาวสมใจรักษ์ ศรีเกษ
# 2156127       14                  นายภัทรเดช สมพล
#
#                                                  image_url
# 0        https://cdn.ectreport.com/images/candidates/พล...
# 1        https://cdn.ectreport.com/images/candidates/นา...
# 2        https://cdn.ectreport.com/images/candidates/นา...
# 3        https://cdn.ectreport.com/images/candidates/รอ...
# 4        https://cdn.ectreport.com/images/candidates/ร้...
# ...                                                    ...
# 2156123  https://cdn.ectreport.com/images/candidates/นา...
# 2156124  https://cdn.ectreport.com/images/candidates/นา...
# 2156125  https://cdn.ectreport.com/images/candidates/นา...
# 2156126  https://cdn.ectreport.com/images/candidates/นา...
# 2156127  https://cdn.ectreport.com/images/candidates/นา...
#
# [2156128 rows x 26 columns]

# %%
find_mashow = find_ma4[['province','name_x','name_y','party_list_vote']]
find_mashow['party_list_vote'] = find_ma4[['party_list_vote']]
find_mashow
# Out:
# <ipython-input-61-ba6c5e97e687>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   find_mashow['party_list_vote'] = find_ma4[['party_list_vote']]
#          province     name_x                           name_y  party_list_vote
# 0        ร้อยเอ็ด   เพื่อไทย      พลตำรวจโท วิโรจน์ เปาอินทร์            83851
# 1        ร้อยเอ็ด   เพื่อไทย             นายสมพงษ์ อมรวิวัฒน์            83851
# 2        ร้อยเอ็ด   เพื่อไทย          นายประเสริฐ จันทรรวงทอง            83851
# 3        ร้อยเอ็ด   เพื่อไทย  รองศาสตราจารย์ ชูศักดิ์ ศิรินิล            83851
# 4        ร้อยเอ็ด   เพื่อไทย     ร้อยตำรวจเอก เฉลิม อยู่บำรุง            83851
# ...           ...        ...                              ...              ...
# 2156123  เพชรบุรี  พลังสังคม              นางสาวพัชรี เย็นแพง                0
# 2156124  เพชรบุรี  พลังสังคม     นางสาวพรรณลักษณ์ นพลักษณ์กุล                0
# 2156125  เพชรบุรี  พลังสังคม                   นายพิทัต ผลทวี                0
# 2156126  เพชรบุรี  พลังสังคม           นางสาวสมใจรักษ์ ศรีเกษ                0
# 2156127  เพชรบุรี  พลังสังคม                  นายภัทรเดช สมพล                0
#
# [2156128 rows x 4 columns]

# %%
use_V0=find_mashow[['name_x','name_y','party_list_vote']]
prov_vote=find_mashow.groupby('province')[['party_list_vote']].max().reset_index()
use_V1 = prov_vote.merge(use_V0,how='left', on='party_list_vote')
bool_use = use_V1.duplicated(subset='province')
use_V1 = use_V1[~bool_use]
# displaying data
use_V1.info()
use_V1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77 entries, 0 to 20148
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   province         77 non-null     object
#  1   party_list_vote  77 non-null     int64
#  2   name_x           77 non-null     object
#  3   name_y           77 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 3.0+ KB
#             province  party_list_vote    name_x                       name_y
# 0             กระบี่            31614   ก้าวไกล       นายพิธา ลิ้มเจริญรัตน์
# 184    กรุงเทพมหานคร            54268   ก้าวไกล       นายพิธา ลิ้มเจริญรัตน์
# 368        กาญจนบุรี            41531   ก้าวไกล       นายพิธา ลิ้มเจริญรัตน์
# 552        กาฬสินธุ์            50454  เพื่อไทย  พลตำรวจโท วิโรจน์ เปาอินทร์
# 1052       กำแพงเพชร            40145   ก้าวไกล       นายพิธา ลิ้มเจริญรัตน์
# ...              ...              ...       ...                          ...
# 19288       เพชรบุรี            38451   ก้าวไกล       นายพิธา ลิ้มเจริญรัตน์
# 19472      เพชรบูรณ์            35539   ก้าวไกล       นายพิธา ลิ้มเจริญรัตน์
# 19748            เลย            41419  เพื่อไทย  พลตำรวจโท วิโรจน์ เปาอินทร์
# 19948           แพร่            41265  เพื่อไทย  พลตำรวจโท วิโรจน์ เปาอินทร์
# 20148     แม่ฮ่องสอน            29892   ก้าวไกล       นายพิธา ลิ้มเจริญรัตน์
#
# [77 rows x 4 columns]

# %%
find_mashow =find_ma4[['province','name','mp_app_name']]
find_mashow['mp_app_vote_'] = find_ma4[['mp_app_vote']]
find_mashow
# Out:
# <ipython-input-36-9fd55a1fecaa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   find_mashow['mp_app_vote_'] = find_ma4[['mp_app_vote']]
#           province            name               mp_app_name  mp_app_vote_
# 0             ตรัง    พลังประชารัฐ            นายทวี สุระบาล         63185
# 1             ตรัง    พลังประชารัฐ            นายทวี สุระบาล         63185
# 2             ตรัง    พลังประชารัฐ            นายทวี สุระบาล         63185
# 3      อุบลราชธานี  เพื่อไทรวมพลัง      นายสมศักดิ์ บุญประชม         63127
# 4      อุบลราชธานี  เพื่อไทรวมพลัง      นายสมศักดิ์ บุญประชม         63127
# ...            ...             ...                       ...           ...
# 13503        สงขลา         คลองไทย        นางลักขณา บุญรักษ์             0
# 13504      นนทบุรี       พลังสังคม  นายรัฐศิลป์ นลินธนาพัฒน์             0
# 13505      นนทบุรี       พลังสังคม  นายรัฐศิลป์ นลินธนาพัฒน์             0
# 13506        สงขลา         คลองไทย           นายมีชัย เทศนอก             0
# 13507        สงขลา         คลองไทย           นายมีชัย เทศนอก             0
#
# [13508 rows x 4 columns]

# %%
use_V0=find_mashow[['name','mp_app_name','mp_app_vote_']]
prov_vote=find_mashow.groupby('province')[['mp_app_vote_']].max().reset_index()
use_V1 = prov_vote.merge(use_V0,how='left', on='mp_app_vote_')
bool_use = use_V1.duplicated(subset='province')
use_V1 = use_V1[~bool_use]
# displaying data
use_V1.info()
use_V1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77 entries, 0 to 232
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   province      77 non-null     object
#  1   mp_app_vote_  77 non-null     int64
#  2   name          77 non-null     object
#  3   mp_app_name   77 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 3.0+ KB
#           province  mp_app_vote_             name                mp_app_name
# 0           กระบี่         51845        ภูมิใจไทย    นายสฤษฏ์พงษ์ เกี่ยวข้อง
# 4    กรุงเทพมหานคร         50132          ก้าวไกล      นายศุภณัฐ มีนชัยนันท์
# 7        กาญจนบุรี         44813        ภูมิใจไทย      นายยศวัฒน์ มาไพศาลสิน
# 9        กาฬสินธุ์         56559         เพื่อไทย        นายวิรัช พิมพะนิตย์
# 12       กำแพงเพชร         41143     พลังประชารัฐ    นายเพชรภูมิ อาภรณ์รัตน์
# ..             ...           ...              ...                        ...
# 221       เพชรบุรี         40235  รวมไทยสร้างชาติ  นางธิวัลรัตน์ อังกินันทน์
# 223      เพชรบูรณ์         47118     พลังประชารัฐ            นายอัคร ทองใจสด
# 225            เลย         50421         เพื่อไทย        นายศรัณย์ ทิมสุวรรณ
# 230           แพร่         41565         เพื่อไทย          นายทศพร เสรีรักษ์
# 232     แม่ฮ่องสอน         20346     ประชาธิปัตย์         นายสมบัติ ยะสินธุ์
#
# [77 rows x 4 columns]

# %% [markdown]
# ##ข้อ 2.1

# %%
find_ma = result_constituencies_Candidate.sort_values(by='mp_app_vote',ascending=False)
find_ma1 = find_ma.merge(info_constituency,how='left', on='cons_id')
find_ma2 = find_ma1.merge(info_province,how='left', on='prov_id')
find_ma3 = find_ma2.merge(info_party_overview,how='left', left_on='party_id',right_on='id')
find_ma4 = find_ma3.merge(Candidate_Constituency,how='left', on='mp_app_id')
find_ma4
# Out:
#       cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0       TRG_2   TRG_2_6            1        63185             60.29103
# 1       TRG_2   TRG_2_6            1        63185             60.29103
# 2       TRG_2   TRG_2_6            1        63185             60.29103
# 3      UBN_10  UBN_10_1            1        63127             62.27446
# 4      UBN_10  UBN_10_1            1        63127             62.27446
# ...       ...       ...          ...          ...                  ...
# 13503   SKA_2  SKA_2_12           12            0              0.00000
# 13504   NBI_8   NBI_8_9           11            0              0.00000
# 13505   NBI_8   NBI_8_9           11            0              0.00000
# 13506   SKA_9  SKA_9_12           13            0              0.00000
# 13507   SKA_9  SKA_9_12           13            0              0.00000
#
#        party_id  cons_no prov_id  registered_vote  total_vote_stations_x  ...  \
# 0           743        2     TRG           130639                    268  ...
# 1           743        2     TRG           130639                    268  ...
# 2           743        2     TRG           130639                    268  ...
# 3           773       10     UBN           139504                    302  ...
# 4           773       10     UBN           139504                    302  ...
# ...         ...      ...     ...              ...                    ...  ...
# 13503       742        2     SKA           109814                    175  ...
# 13504       745        8     NBI           132133                    171  ...
# 13505       745        8     NBI           132133                    171  ...
# 13506       742        9     SKA           127785                    168  ...
# 13507       742        9     SKA           127785                    168  ...
#
#         id  party_no            name    abbr    color  \
# 0      743      37.0    พลังประชารัฐ   พปชร.  #1f68dd
# 1      743      37.0    พลังประชารัฐ   พปชร.  #1f68dd
# 2      743      37.0    พลังประชารัฐ   พปชร.  #1f68dd
# 3      773      38.0  เพื่อไทรวมพลัง    พทล.  #a7b0ed
# 4      773      38.0  เพื่อไทรวมพลัง    พทล.  #a7b0ed
# ...    ...       ...             ...     ...      ...
# 13503  742      61.0         คลองไทย   คล.ท.  #0eafeb
# 13504  745      53.0       พลังสังคม  พ.พ.ส.  #c67328
# 13505  745      53.0       พลังสังคม  พ.พ.ส.  #c67328
# 13506  742      61.0         คลองไทย   คล.ท.  #0eafeb
# 13507  742      61.0         คลองไทย   คล.ท.  #0eafeb
#
#                                                 logo_url  \
# 0      https://cdn.ectreport.com/images/logos/พลังประ...
# 1      https://cdn.ectreport.com/images/logos/พลังประ...
# 2      https://cdn.ectreport.com/images/logos/พลังประ...
# 3      https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4      https://cdn.ectreport.com/images/logos/เพื่อไท...
# ...                                                  ...
# 13503  https://cdn.ectreport.com/images/logos/คลองไทย...
# 13504  https://cdn.ectreport.com/images/logos/พลังสัง...
# 13505  https://cdn.ectreport.com/images/logos/พลังสัง...
# 13506  https://cdn.ectreport.com/images/logos/คลองไทย...
# 13507  https://cdn.ectreport.com/images/logos/คลองไทย...
#
#                     mp_app_name mp_app_no mp_app_party_id  \
# 0                นายทวี สุระบาล         6             743
# 1                นายทวี สุระบาล         6             743
# 2                นายทวี สุระบาล         6             743
# 3          นายสมศักดิ์ บุญประชม         1             773
# 4          นายสมศักดิ์ บุญประชม         1             773
# ...                         ...       ...             ...
# 13503        นางลักขณา บุญรักษ์        12             742
# 13504  นายรัฐศิลป์ นลินธนาพัฒน์         9             745
# 13505  นายรัฐศิลป์ นลินธนาพัฒน์         9             745
# 13506           นายมีชัย เทศนอก        12             742
# 13507           นายมีชัย เทศนอก        12             742
#
#                                                image_url
# 0      https://cdn.ectreport.com/images/mp_candidates...
# 1      https://cdn.ectreport.com/images/mp_candidates...
# 2      https://cdn.ectreport.com/images/mp_candidates...
# 3      https://cdn.ectreport.com/images/mp_candidates...
# 4      https://cdn.ectreport.com/images/mp_candidates...
# ...                                                  ...
# 13503  https://cdn.ectreport.com/images/mp_candidates...
# 13504  https://cdn.ectreport.com/images/mp_candidates...
# 13505  https://cdn.ectreport.com/images/mp_candidates...
# 13506  https://cdn.ectreport.com/images/mp_candidates...
# 13507  https://cdn.ectreport.com/images/mp_candidates...
#
# [13508 rows x 29 columns]

# %% [markdown]
# #ข้อ 2

# %% [markdown]
# พรรคก้าวไกล

# %%
find_proforcon1 = result_constituencies_Candidate.merge(info_party_overview,how='left', left_on='party_id',right_on='id')
find_proforcon = find_proforcon1.merge(Candidate_Constituency,how='left', on='mp_app_id')

# %%
fastfor_w = find_proforcon[find_proforcon['name']=='ก้าวไกล']
TOP_fast = fastfor_w[['mp_app_name','mp_app_vote','mp_app_vote_percent']]
TOP_fast_soft = TOP_fast.sort_values(by='mp_app_vote_percent', ascending=False)
TOP_fast_soft
# Out:
#                     mp_app_name  mp_app_vote  mp_app_vote_percent
# 2605  นายปิยวัฒน์ สิริพันธ์พงศ์        10700            279.88491
# 960      นางสาวพุธิตา ชัยอนันต์        62009             54.01387
# 3910          นางสาวนิตยา มีศรี        60282             50.24547
# 386   นายณัฐชา บุญไชยอินสวัสดิ์        50035             49.46907
# 3900         นายวุฒินันท์ บุญชู        49043             48.17110
# ...                         ...          ...                  ...
# 3182      นายโมฮำมัดรอฮมัด มามุ         4558              5.43337
# 2730          นายวรนารถ นันทกิจ         4673              4.24270
# 2678          นายมะซอบือรี สามะ         3622              4.23254
# 3052             นายสุนทร คมคาย         4218              4.15149
# 2688          นายโยฮัน สาตออุมา         3312              3.45709
#
# [396 rows x 3 columns]

# %%
def math_pa(x):
  y=(100*x)/1220778
  return y

# %%
final_TOP1 = TOP_fast_soft.replace(to_replace=279.88491,
           value=math_pa(279.88491)).sort_values(by='mp_app_vote_percent', ascending=False)

# %%
final_TOP1
# Out:
#                     mp_app_name  mp_app_vote  mp_app_vote_percent
# 960      นางสาวพุธิตา ชัยอนันต์        62009            54.013870
# 3910          นางสาวนิตยา มีศรี        60282            50.245470
# 386   นายณัฐชา บุญไชยอินสวัสดิ์        50035            49.469070
# 3900         นายวุฒินันท์ บุญชู        49043            48.171100
# 449        นายธัญธร ธนินวัฒนาธร        49770            47.516760
# ...                         ...          ...                  ...
# 2730          นายวรนารถ นันทกิจ         4673             4.242700
# 2678          นายมะซอบือรี สามะ         3622             4.232540
# 3052             นายสุนทร คมคาย         4218             4.151490
# 2688          นายโยฮัน สาตออุมา         3312             3.457090
# 2605  นายปิยวัฒน์ สิริพันธ์พงศ์        10700             0.022927
#
# [396 rows x 3 columns]

# %% [markdown]
# พรรคเพื่อไทย

# %%
forthai_w = find_proforcon[find_proforcon['name']=='เพื่อไทย']
TOP_thai = forthai_w[['mp_app_name','mp_app_vote','mp_app_vote_percent']]
TOP_thai_soft = TOP_thai.sort_values(by='mp_app_vote_percent', ascending=False)
TOP_thai_soft
# Out:
#                          mp_app_name  mp_app_vote  mp_app_vote_percent
# 2593             นายถาวรวัฒน์ คงแก้ว         5596            146.37719
# 3335           นางสาวจิราพร สินธุไพร        61288             69.34758
# 1077           นายเชิงชาย ชาลีรินทร์        61414             63.43832
# 1579             นายวิรัช พิมพะนิตย์        56559             59.80965
# 2171       นายอาทิตย์ หวังศุภกิจโกศล        60320             58.86831
# ...                              ...          ...                  ...
# 3183           นายอาหมัดบูรฮัน ติพอง          641              0.76410
# 2829           นายชัยจรงค์ ฤทธิสุนทร          823              0.72252
# 3168                นายรุสดี แวบือซา          499              0.71840
# 3493  ร้อยตำรวจตรีสมศักดิ์ แสงประดับ          720              0.70016
# 2670                 นายปักสู แวนามะ          517              0.60415
#
# [400 rows x 3 columns]

# %%
final_TOP2 = TOP_thai_soft.replace(to_replace=146.37719,
           value=math_pa(146.37719)).sort_values(by='mp_app_vote_percent', ascending=False)

# %%
final_TOP2
# Out:
#                          mp_app_name  mp_app_vote  mp_app_vote_percent
# 3335           นางสาวจิราพร สินธุไพร        61288             69.34758
# 1077           นายเชิงชาย ชาลีรินทร์        61414             63.43832
# 1579             นายวิรัช พิมพะนิตย์        56559             59.80965
# 2171       นายอาทิตย์ หวังศุภกิจโกศล        60320             58.86831
# 1407              นายภาควัต ศรีสุรพล        50423             57.89625
# ...                              ...          ...                  ...
# 2829           นายชัยจรงค์ ฤทธิสุนทร          823              0.72252
# 3168                นายรุสดี แวบือซา          499              0.71840
# 3493  ร้อยตำรวจตรีสมศักดิ์ แสงประดับ          720              0.70016
# 2670                 นายปักสู แวนามะ          517              0.60415
# 2593             นายถาวรวัฒน์ คงแก้ว         5596              0.01199
#
# [400 rows x 3 columns]

# %% [markdown]
# พรรคภูมิใจไทย

# %%
poothai_w = find_proforcon[find_proforcon['name']=='ภูมิใจไทย']
TOP_poo = poothai_w[['mp_app_name','mp_app_vote','mp_app_vote_percent']]
TOP_poo_soft = TOP_poo.sort_values(by='mp_app_vote_percent', ascending=False)
TOP_poo_soft
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-126d12d023d9> in <cell line: 1>()
# ----> 1 poothai_w = find_proforcon[find_proforcon['name']=='ภูมิใจไทย']
#       2 TOP_poo = poothai_w[['mp_app_name','mp_app_vote','mp_app_vote_percent']]
#       3 TOP_poo_soft = TOP_poo.sort_values(by='mp_app_vote_percent', ascending=False)
#       4 TOP_poo_soft
#
# NameError: name 'find_proforcon' is not defined

# %%
final_TOP3 = TOP_poo_soft.replace(to_replace=608.42270,
           value=math_pa(608.42270)).sort_values(by='mp_app_vote_percent', ascending=False)
final_TOP3
# Out:
#                     mp_app_name  mp_app_vote  mp_app_vote_percent
# 4658      นายเจเศรษฐ์ ไทยเศรษฐ์        49464            53.663720
# 687             นายโสภณ ซารัมย์        47746            53.101260
# 647            นายไชยชนก ชิดชอบ        46729            52.871030
# 4242  นายวรศิษฎ์ เลียงประสิทธิ์        55612            52.719790
# 1296    นายสฤษฏ์พงษ์ เกี่ยวข้อง        51845            52.130680
# ...                         ...          ...                  ...
# 1581          นางบุณยะพร พิรชัช          123             0.135500
# 3872            นายธนภาค ลี่สิน          128             0.128840
# 1079          นายไตรภูมิ แซ่อึง          115             0.118790
# 2386   นางสาวอมรรัตน์ รุ่งเรือง           95             0.088910
# 2606    นายสมศักดิ์ แสงอารยะกุล        23260             0.049839
#
# [387 rows x 3 columns]

# %% [markdown]
# ## ลอง

# %%
mpvp =find_proforconAB[find_proforconAB['mp_app_vote_percent'] > 100]

# %%
mpvp
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 2593   NST_6   NST_6_1            5         5596            146.37719
# 2594   NST_6  NST_6_10            4         7731            202.22338
# 2601   NST_6   NST_6_4            6         5574            145.80173
# 2602   NST_6   NST_6_5            1        27331            714.90976
# 2605   NST_6   NST_6_8            3        10700            279.88491
# 2606   NST_6   NST_6_9            2        23260            608.42270
#
#       party_id   id  party_no             name   abbr    color  \
# 2593       705  705      29.0         เพื่อไทย    พท.  #da3731
# 2594       763  763      22.0  รวมไทยสร้างชาติ  รทสช.  #aa2d38
# 2601       701  701      26.0     ประชาธิปัตย์   ปชป.  #06aff3
# 2602       743  743      37.0     พลังประชารัฐ  พปชร.  #1f68dd
# 2605       726  726      31.0          ก้าวไกล   ก.ก.  #f47526
# 2606       709  709       7.0        ภูมิใจไทย    ภท.  #0c149c
#
#                                                logo_url  \
# 2593  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 2594  https://cdn.ectreport.com/images/logos/รวมไทยส...
# 2601  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 2602  https://cdn.ectreport.com/images/logos/พลังประ...
# 2605  https://cdn.ectreport.com/images/logos/ก้าวไกล...
# 2606  https://cdn.ectreport.com/images/logos/ภูมิใจไ...
#
#                     mp_app_name  mp_app_no  mp_app_party_id  \
# 2593        นายถาวรวัฒน์ คงแก้ว          1              705
# 2594         นายฉัตรชัย ธนาวุฒิ         10              763
# 2601        นายประกอบ รัตนพันธ์          4              701
# 2602          นายสุธรรม จริตงาม          5              743
# 2605  นายปิยวัฒน์ สิริพันธ์พงศ์          8              726
# 2606    นายสมศักดิ์ แสงอารยะกุล          9              709
#
#                                               image_url
# 2593  https://cdn.ectreport.com/images/mp_candidates...
# 2594  https://cdn.ectreport.com/images/mp_candidates...
# 2601  https://cdn.ectreport.com/images/mp_candidates...
# 2602  https://cdn.ectreport.com/images/mp_candidates...
# 2605  https://cdn.ectreport.com/images/mp_candidates...
# 2606  https://cdn.ectreport.com/images/mp_candidates...

# %%
list(mpvp['mp_app_vote_percent'])
# Out:
# [146.37719, 202.22338, 145.80173, 714.90976, 279.88491, 608.4227]

# %%
l = []
for i in list(mpvp['mp_app_vote_percent']):
  b = math_pa(i)
  l.append(b)
mpvp['mp_app_vote_percent'] = l
# Out:
# <ipython-input-73-9942be42020c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mpvp['mp_app_vote_percent'] = l

# %% [markdown]
# #เช็กcolumns เเละเก็บข้อมูลเป็น csv

# %%
table_merge3.columns
# Out:
# Index(['cons_id', 'mp_app_id', 'mp_app_rank', 'mp_app_vote',
#        'mp_app_vote_percent', 'party_id', 'mp_app_name', 'mp_app_no',
#        'mp_app_party_id', 'image_url', 'id', 'party_no', 'name', 'abbr',
#        'color', 'logo_url', 'prov_id', 'turn_out', 'percent_turn_out',
#        'counted_vote_stations', 'percent_count', 'pause_report', 'province_id',
#        'province', 'eng', 'abbre_thai', 'total_registered_vote',
#        'total_vote_stations', 'region_id'],
#       dtype='object')

# %%
use_V1.to_csv('party_list_2.csv', index=False)

# %%
use_V1.to_csv('use_V1.csv', index=False)

# %%
final_TOP1.to_csv('ข้อมูลก้าวไกล.csv', index=False)

# %%
final_TOP2.to_csv('ข้อมูลเพื่อไทย.csv', index=False)

# %%
final_TOP3.to_csv('ข้อมูลภูมิใจไทย.csv', index=False)
