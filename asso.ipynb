# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonry12/data_science_bootcamp_8_tonnaw/blob/main/asso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
asso = pd.read_excel('/content/drive/MyDrive/DPDM2023/association.xlsx')

# %%
asso_act = asso[asso['กิจกรรม_2564'] !='-']

# %%
asso
# Out:
#                     กิจกรรม_2564  \
# 0                 (1)ปั่นจักรยาน
# 1                              -
# 2                              -
# 3                        (1)วิ่ง
# 4                 (1)ปั่นจักรยาน
# ...                          ...
# 20093            (1)เดิน,(2)วิ่ง
# 20094          (1)เดิน,(2)ฟุตบอล
# 20095  (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096                    (1)เดิน
# 20097              (1)วอลเลย์บอล
#
#                                             เหตุผล (ออก)
# 0      ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี/ห...
# 1                                                      -
# 2                                                      -
# 3      ต้องการให้ร่างกายแข็งแรง,ควบคุมน้ำหนัก/ลดน้ำหน...
# 4      ต้องการให้ร่างกายแข็งแรง,รักษา/บรรเทาอาการเจ็บ...
# ...                                                  ...
# 20093                   ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
# 20094                           ต้องการให้ร่างกายแข็งแรง
# ...

# %%
asso_act_c = asso_act[['เหตุผล (ออก)']]

# %%
asso_act_c[['act_1']] = asso_act_c['เหตุผล (ออก)'].str.split('/', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-9101927a3431> in <cell line: 1>()
# ----> 1 asso_act_c[['act_1']] = asso_act_c['เหตุผล (ออก)'].str.split('/', expand=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3966             self._setitem_frame(key, value)
#    3967         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968             self._setitem_array(key, value)
#    3969         elif isinstance(value, DataFrame):
#    3970             self._set_item_frame_value(key, value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    4008
#    4009             if isinstance(value, DataFrame):
# -> 4010                 check_key_length(self.columns, key, value)
#    4011                 for k1, k2 in zip(key, value.columns):
# ...

# %%
asso_act_c_t = asso_act_c['เหตุผล (ออก)'].str.split('/', expand=True)

# %%
asso_act_c_t
# Out:
#                                                      0  \
# 0         ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี
# 3               ต้องการให้ร่างกายแข็งแรง,ควบคุมน้ำหนัก
# 4                       ต้องการให้ร่างกายแข็งแรง,รักษา
# 5                                           คลายเครียด
# 7                                        เป็นงานต้องทำ
# ...                                                ...
# 20093                           ทำกิจกรรมร่วมกับเพื่อน
# 20094                         ต้องการให้ร่างกายแข็งแรง
# 20095                           ทำกิจกรรมร่วมกับเพื่อน
# 20096  ต้องการให้ร่างกายแข็งแรง,ทำกิจกรรมร่วมกับเพื่อน
# 20097                           ทำกิจกรรมร่วมกับเพื่อน
#
#                                                      1  \
# 0                                 หุ่นดี,ควบคุมน้ำหนัก
# 3                             ลดน้ำหนัก,ชอบออกกำลังกาย
# 4                    บรรเทาอาการเจ็บป่วย,ควบคุมน้ำหนัก
# 5                                              พักผ่อน
# ...

# %%
asso_act_c_t['เหตุผล (ออก)'].str.split(',', expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-e637f41bda32> in <cell line: 1>()
# ----> 1 asso_act_c_t['เหตุผล (ออก)'].str.split(',', expand=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     393                     raise KeyError(key) from err
#     394             self._check_indexing_error(key)
# --> 395             raise KeyError(key)
#     396         return super().get_loc(key, method=method, tolerance=tolerance)
#     397
#
# ...

# %%
df[['First Name', 'Last Name']] = df['Name'].str.split(' ', expand=True)
